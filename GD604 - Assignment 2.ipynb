# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/aseks/Downloads/Sales_Sample_Public_Dataset.csv', encoding='ISO-8859-1')

# %%
df.head(3)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
#
#         ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0  2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  5/07/2003 0:00  Shipped       2         5     2003  ...
# 2  7/01/2003 0:00  Shipped       3         7     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2   CITY STATE POSTALCODE  \
# 0        897 Long Airport Avenue           NaN    NYC    NY      10022
# 1             59 rue de l'Abbaye           NaN  Reims   NaN      51100
# 2  27 rue du Colonel Pierre Avia           NaN  Paris   NaN      75508
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0     USA       NaN              Yu             Kwai    Small
# ...

# %%
missing_values = df.isna().sum()

print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df['ADDRESSLINE2'] = df['ADDRESSLINE2'].fillna('Unknown')
df['TERRITORY'] = df['TERRITORY'].fillna('Unknown')
df['POSTALCODE'] = df['POSTALCODE'].fillna('Unknown')

# %%
df['STATE'] = df['STATE'].fillna(df['STATE'].mode()[0])

# %%
missing_values = df.isna().sum()
print("Missing values per column after imputation:")
print(missing_values)
# Out:
# Missing values per column after imputation:
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# ADDRESSLINE2         0
# CITY                 0
# STATE                0
# POSTALCODE          76
# COUNTRY              0
# TERRITORY            0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
df['POSTALCODE'] = df['POSTALCODE'].fillna(df['POSTALCODE'].mode()[0])

# %%
missing_values = df.isna().sum()
print("Missing values per column after imputation:")
print(missing_values)
# Out:
# Missing values per column after imputation:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df_sorted_by_sales = df.sort_values(by='SALES', ascending=False)
print(df_sorted_by_sales.head())
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 53          10424               50      100.0                6  12001.0
# 1062        10412               60      100.0                9  11887.8
# 104         10403               66      100.0                9  11886.6
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 598    4/22/2005 0:00     On Hold       2         4     2005  ...
# 744   11/04/2004 0:00     Shipped       4        11     2004  ...
# 53     5/31/2005 0:00  In Process       2         5     2005  ...
# 1062   5/03/2005 0:00     Shipped       2         5     2005  ...
# 104    4/08/2005 0:00     Shipped       2         4     2005  ...
#
#                       ADDRESSLINE1  ADDRESSLINE2       CITY STATE POSTALCODE  \
# ...

# %%
high_value_transactions = df_sorted_by_sales[df_sorted_by_sales['SALES'] > 5000]
print(high_value_transactions.head())
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 53          10424               50      100.0                6  12001.0
# 1062        10412               60      100.0                9  11887.8
# 104         10403               66      100.0                9  11886.6
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 598    4/22/2005 0:00     On Hold       2         4     2005  ...
# 744   11/04/2004 0:00     Shipped       4        11     2004  ...
# 53     5/31/2005 0:00  In Process       2         5     2005  ...
# 1062   5/03/2005 0:00     Shipped       2         5     2005  ...
# 104    4/08/2005 0:00     Shipped       2         4     2005  ...
#
#                       ADDRESSLINE1  ADDRESSLINE2       CITY STATE POSTALCODE  \
# ...

# %%
profit_margin = 0.20
df['PROFIT'] = df['SALES'] * profit_margin
print(df[['ORDERNUMBER', 'SALES', 'PROFIT']].head())
# Out:
#    ORDERNUMBER    SALES    PROFIT
# 0        10107  2871.00   574.200
# 1        10121  2765.90   553.180
# 2        10134  3884.34   776.868
# 3        10145  3746.70   749.340
# 4        10159  5205.27  1041.054

# %%
sales_by_dealsize = df.groupby('DEALSIZE')['SALES'].sum().reset_index()
print(sales_by_dealsize)
# Out:
#   DEALSIZE       SALES
# 0    Large  1302119.26
# 1   Medium  6087432.24
# 2    Small  2643077.35

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP  \
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...      Unknown
# ...

# %%
grouped_data = df.groupby('DEALSIZE')

# %%
grouped_data = df.groupby('DEALSIZE')[['SALES', 'PROFIT']].agg(['mean', 'median', 'sum', 'count', 'std']).reset_index()
grouped_data
# Out:
#   DEALSIZE        SALES                                               PROFIT  \
#                    mean    median         sum count          std        mean
# 0    Large  8293.753248  8008.560  1302119.26   157  1294.739895  1658.75065
# 1   Medium  4398.433699  4162.750  6087432.24  1384  1047.090148   879.68674
# 2    Small  2061.682800  2113.975  2643077.35  1282   577.183322   412.33656
#
#
#      median          sum count         std
# 0  1601.712   260423.852   157  258.947979
# 1   832.550  1217486.448  1384  209.418030
# 2   422.795   528615.470  1282  115.436664

# %%
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# %%
correlation_matrix = numerical_df.corr()
correlation_matrix
# Out:
#                  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# ORDERNUMBER         1.000000         0.065543  -0.002935        -0.055550
# QUANTITYORDERED     0.065543         1.000000   0.005564        -0.018397
# PRICEEACH          -0.002935         0.005564   1.000000        -0.020965
# ORDERLINENUMBER    -0.055550        -0.018397  -0.020965         1.000000
# SALES               0.039919         0.551426   0.657841        -0.058400
# QTR_ID             -0.051383        -0.035323   0.008712         0.040716
# MONTH_ID           -0.039723        -0.039048   0.005152         0.034016
# YEAR_ID             0.904596         0.069535  -0.005938        -0.057367
# MSRP               -0.010280         0.017881   0.670625        -0.021067
# PROFIT              0.039919         0.551426   0.657841        -0.058400
#
#                     SALES    QTR_ID  MONTH_ID   YEAR_ID      MSRP    PROFIT
# ORDERNUMBER      0.039919 -0.051383 -0.039723  0.904596 -0.010280  0.039919
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
df.to_csv('C:/Users/aseks/Downloads/Exported_Sales_Data.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Scatter plot to visualize the relationship between Sales and Profit
plt.figure(figsize=(8, 6))
plt.scatter(df['SALES'], df['PROFIT'], alpha=0.5, color='blue')
plt.title('Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['QUANTITYORDERED'], df['SALES'], alpha=0.5, color='green')
plt.title('Quantity Ordered vs. Sales')
plt.xlabel('Quantity Ordered')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['PRICEEACH'], df['SALES'], alpha=0.5, color='purple')
plt.title('Price Each vs. Sales')
plt.xlabel('Price Each')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
deal_size_distribution = df['DEALSIZE'].value_counts()

deal_size_distribution.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'green', 'coral'])
plt.title('Distribution of Deal Sizes')
plt.ylabel('')  # Hide the y-label
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='DEALSIZE', y='SALES', data=df, hue='DEALSIZE', palette='pastel', legend=False)
plt.title('Sales Distribution by Deal Size')
plt.xlabel('Deal Size')
plt.ylabel('Sales')
plt.show()

# %%
from scipy.stats import ttest_ind

small_sales = df[df['DEALSIZE'] == 'Small']['SALES']
large_sales = df[df['DEALSIZE'] == 'Large']['SALES']

t_stat, p_val = ttest_ind(small_sales, large_sales, equal_var=False)

print(f"T-Statistic: {t_stat:.4f}, P-Value: {p_val:.4f}")
# Out:
# T-Statistic: -59.5907, P-Value: 0.0000
